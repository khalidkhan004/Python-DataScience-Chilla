# %% [markdown]
# # Regression in Scikit-learn

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#other
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# import dataset
df =sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_linear = df[['age' ,'fare']]

# %%
df_linear
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
# simple linear regression
x=df[['age']]
y=df['fare']

# %%
df_linear.age.fillna(value=df_linear['age'].mean() ,inplace=True)
# Out:
# C:\Users\Afaq khalid\AppData\Local\Temp\ipykernel_14008\2253802935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_linear.age.fillna(value=df_linear['age'].mean() ,inplace=True)

# %%
x.isnull().sum() /len(x) *100
# Out:
# age    0.0
# dtype: float64

# %%
x.shape
# Out:
# (891, 1)

# %%
y.shape
# Out:
# (891,)

# %%
# plot
sns.lmplot(data=df_linear ,x='age' ,y='fare')

# %%
sns.boxplot(data=df_linear ,y='age')
# Out:
# <AxesSubplot: ylabel='age'>

# %%
df_linear=df_linear[(df_linear['age'] >8) & (df_linear['age'] <50)]

# %%
sns.boxplot(data=df_linear ,y='age')
# Out:
# <AxesSubplot: ylabel='age'>

# %%
sns.boxplot(data=df_linear ,y='fare')
# Out:
# <AxesSubplot: ylabel='fare'>

# %%
df_linear=df_linear[(df_linear['fare'] >1) & (df_linear['fare'] <40)]

# %%
sns.boxplot(data=df_linear ,y='fare')
# Out:
# <AxesSubplot: ylabel='fare'>

# %%
x=df_linear[['age']]
y=df_linear['fare']

# %%
# plot
sns.lmplot(data=df_linear ,x='age' ,y='fare')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# model to call kare
model=LinearRegression()

# train the model
model.fit(x,y)

# prediction
model.predict([[55]])
# Out:
# c:\Users\Afaq khalid\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18.7162485])

# %%
# Out:
# c:\Users\Afaq khalid\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18.7162485])

# %%
x_train ,x_test ,y_train ,y_test = train_test_split(x,y ,train_size=0.8)

#model
model=LinearRegression()

# train
model.fit(x_train ,y_train)

# prediction
predictions=model.predict(x_test)

# %%
# compare
sns.scatterplot(x=y_test ,y=predictions)
# Out:
# <AxesSubplot: xlabel='fare'>

# %%
from sklearn.metrics import mean_squared_error ,mean_absolute_error,r2_score
MAE=mean_absolute_error(y_true=y_test ,y_pred=predictions)
MSE=mean_squared_error(y_true=y_test ,y_pred=predictions)
RMSE=mean_squared_error(y_true=y_test ,y_pred=predictions,squared=False)
R2=r2_score(y_true=y_test ,y_pred=predictions)

print("MAE:" ,MAE)
print("MSE:" ,MSE)
print("RMSE:" ,RMSE)
print("R2:" ,R2)
# Out:
# MAE: 5.739988735101797
# MSE: 45.8891026471877
# RMSE: 6.774149588486196
# R2: 0.010125145888266518
